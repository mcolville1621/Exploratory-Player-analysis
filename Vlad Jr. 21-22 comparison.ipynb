# %%
from pybaseball import batting_stats

# %%
bat = batting_stats(2021, 2022)
#list(bat.columns)
# Out:
# ['IDfg',
#  'Season',
#  'Name',
#  'Team',
#  'Age',
#  'G',
#  'AB',
#  'PA',
#  'H',
#  '1B',
#  '2B',
#  '3B',
#  'HR',
#  'R',
#  'RBI',
#  'BB',
#  'IBB',
#  'SO',
#  'HBP',
#  'SF',
#  'SH',
#  'GDP',
#  'SB',
#  'CS',
#  'AVG',
#  'GB',
#  'FB',
#  'LD',
#  'IFFB',
#  'Pitches',
#  'Balls',
#  'Strikes',
#  'IFH',
#  'BU',
#  'BUH',
#  'BB%',
#  'K%',
#  'BB/K',
#  'OBP',
#  'SLG',
#  'OPS',
#  'ISO',
#  'BABIP',
#  'GB/FB',
#  'LD%',
#  'GB%',
#  'FB%',
#  'IFFB%',
#  'HR/FB',
#  'IFH%',
#  'BUH%',
#  'wOBA',
#  'wRAA',
#  'wRC',
#  'Bat',
#  'Fld',
#  'Rep',
#  'Pos',
#  'RAR',
#  'WAR',
#  'Dol',
#  'Spd',
#  'wRC+',
#  'WPA',
#  '-WPA',
#  '+WPA',
#  'RE24',
#  'REW',
#  'pLI',
#  'phLI',
#  'PH',
#  'WPA/LI',
#  'Clutch',
#  'FB% (Pitch)',
#  'FBv',
#  'SL%',
#  'SLv',
#  'CT%',
#  'CTv',
#  'CB%',
#  'CBv',
#  'CH%',
#  'CHv',
#  'SF%',
#  'SFv',
#  'KN%',
#  'KNv',
#  'XX%',
#  'PO%',
#  'wFB',
#  'wSL',
#  'wCT',
#  'wCB',
#  'wCH',
#  'wSF',
#  'wKN',
#  'wFB/C',
# ...

# %%
vlad = bat.query('Name == "Vladimir Guerrero Jr."')

# %%
Vlad = vlad.set_index('Season')
Vlad[['PA', 'HR', 'R', 'RBI', 'K%', 'BB%', 'AVG', 'wOBA', 'BABIP', 'SLG', 'OPS', 'ISO', 'wRC+', 'LD%', 'GB%', 'FB%', 'O-Swing%', 'Z-Swing%', 'Z-Contact%', 'O-Contact%', 'Contact%', 'Swing%', 'Pull%', 'Cent%', 'Oppo%', 'Soft%', 'Med%', 'Hard%', 'EV', 'LA', 'Barrel%', 'HardHit%', 'maxEV', 'SwStr%', 'CSW%']].T
# Out:
# Season         2021     2022
# PA          698.000  558.000
# HR           48.000   27.000
# R           123.000   74.000
# RBI         111.000   80.000
# K%            0.158    0.159
# BB%           0.123    0.086
# AVG           0.311    0.285
# wOBA          0.419    0.367
# BABIP         0.313    0.298
# SLG           0.601    0.504
# OPS           1.002    0.855
# ISO           0.290    0.219
# wRC+        166.000  142.000
# LD%           0.188    0.183
# GB%           0.448    0.514
# FB%           0.365    0.303
# O-Swing%      0.283    0.329
# Z-Swing%      0.761    0.731
# Z-Contact%    0.840    0.878
# O-Contact%    0.558    0.656
# Contact%      0.739    0.786
# Swing%        0.473    0.487
# Pull%         0.399    0.382
# Cent%         0.355    0.380
# Oppo%         0.246    0.238
# Soft%         0.107    0.154
# Med%          0.476    0.457
# Hard%         0.417    0.389
# EV           95.100   92.900
# LA            9.400    4.500
# Barrel%       0.151    0.118
# ...

# %% [markdown]
# ### Given he has still a month left - not nearly as many HR, R, RBI
# ## Walking less. BA is down as well as wOBA and BABIP
# ## Power metrics are all down
# ## More ground balls, less fly balls
# ## Swinging more at outside balls and in general, but making more contact
# ## more balls going up the center than elsewhere
# ## Making worse contact (Soft) and good (hard) contact is down a lot - which lead to a poor barrel rate
# ### hard hit rate down a bit as well
# ## Launch angle is almost half of what it was last year
# ### velocity has stayed roughly the same

# %% [markdown]
# # To summarize- Vlads power, BA and BB% are all worse than last year
# ## This can be seen in Launch angle being down a lot , making worse contact, and swinging at more outside balls and swinging more in general
# ## Making more Ground balls which are more often going up the center than anywhere else
# ### Something may have happened to his swing or plate discipline from last year or opposing pitchers may have found out how to pitch to him
